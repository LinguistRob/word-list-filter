# %%
import csv
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re


def create_new_list_file(tl):
    """
    This is the main file that gets called, iterating through the list of languages to run the task for.
    It takes a language, runs get_unmatched_words()
    and saves the result to a new file with the name 'new_{language}_WordList.tsv'
    """
    global language
    language = tl
    unmatched_words = get_unmatched_words()
    with open(f"FilteredLists/new_{language}_WordList.tsv", 'w') as new_file:
        tsv_writer = csv.writer(new_file, delimiter='\t')
        for word in unmatched_words:
            tsv_writer.writerow([word])


def get_word_list():
    """
    Reads the '{language}_WordList.tsv' file and returns the list of words minus the header row
    """
    word_list = []
    with open(f'./FreqWordLists/{language}_WordList.tsv', 'r') as wl_file:
        for row in wl_file:
            word_list.append(row.strip('\n'))
        return word_list[1:]


def get_target_item_list():
    """
    Reads a list of target items in a .tsv file named with the format:
        {language}_TargetItems.tsv      (e.g. italian_TargetItems.tsv)
    It then takes the first column of each row, adds it to a list.
    """
    target_item_list = []
    with open(f'./TargetItemLists/{language}_TargetItems.tsv', 'r') as ti_file:
        rd = csv.reader(ti_file, delimiter="\t", quotechar='"')
        for row in rd:
            target_item_list.append(row[0])
    target_item_list = target_item_list[1:]  # set the list equal to all rows minus the header row
    return clean_target_items(target_item_list)

# %%
def get_unmatched_words():
    """
    Takes a language name and returns a list of words
    from the corresponding word list that don't match stopwords or target items.
    The proper noun filtering doesn't work well, so it's being excluded.
    """
    word_list = get_word_list()
    target_item_list = get_target_item_list()
    unmatched_words = []
    removed_stopwords = []
    removed_target_items = []
    removed_proper_nouns = []

    for word in word_list:
        if language == 'korean' or language == 'japanese':
            if is_target_item(word, target_item_list):
                removed_target_items.append(word)
            else:
                unmatched_words.append(word)
        else:
            if is_stopword(word):
                removed_stopwords.append(word)
            elif is_target_item(word, target_item_list):
                removed_target_items.append(word)
            # elif is_proper_noun(word):
            #     removed_proper_nouns.append(word)
            else:
                unmatched_words.append(word)
    all_removed_words = removed_target_items + removed_stopwords + removed_proper_nouns
    print(f"-------------\n{language.upper()}\nFound {len(unmatched_words)} unmatched words in {language.title()} from the list of {len(word_list)} words")
    print(f"""
Removed {len(all_removed_words)} words from the word list
>> {len(removed_stopwords)} were stopwords:
    {removed_stopwords}""")
#     print(f"""
# >> {len(removed_proper_nouns)} were proper nouns:
#     {removed_proper_nouns}""")
    print(f"""
>> {len(removed_target_items)} already exist in CAS:
    {removed_target_items}
    """)
    # print("Words matched to existing items in CAS:")
    # print(removed_target_items)
    # print("Proper nouns removed:")
    # print(removed_proper_nouns)
    return unmatched_words



def is_proper_noun(word):
    """
    Returns True if the given word is a proper noun
    """
    word_as_list = [word]
    tagged_word = nltk.pos_tag(word_as_list)
    if tagged_word[0][1] == 'NNP':
        return True
    return False


def is_stopword(word):
    """
    Returns True if the word checked matches any of the stopwords from the nltk corpus
    """
    stop_words = stopwords.words(language)
    if word in stop_words:
        return True
    return False


def is_target_item(word, target_item_list):
    """
    Checks a word against the target item list and returns True if it is a target item
    """
    if word in target_item_list:
        return True
    return False

# %% [markdown]
# The following functions clean up the target items to improve matching with the word list. The Stopwords and tokenization don't work for Korean and Japanese, so they are treated separetely.

# %%
def clean_target_items(ti_list):
    """
    Takes a list of target items and returns the list with the strings cleaned
    """
    clean_list = []
    if language == 'korean' or language == 'japanese':
        for item in ti_list:
            item_no_punctuation = re.sub('\W+', ' ', item)
            if item_no_punctuation != '':
                clean_list.append(item_no_punctuation)
    else:
        for item in ti_list:
            item_no_semicolon = get_str_before_semicolon(item)
            item_no_apostrophe = get_str_after_apostrophe(item_no_semicolon)
            item_no_punctuation = re.sub('\W+', ' ', item_no_apostrophe)
            item_no_stopwords_list = [word for word in word_tokenize(item_no_punctuation, language) if not is_stopword(word)]
            clean_item = ' '.join(item_no_stopwords_list)
            # print(item, "\n>> ", clean_item, "\n----------------\n")
            if clean_item != '':
                clean_list.append(clean_item)
    return clean_list


def get_str_before_semicolon(item):
    """
    If the item contains a semicolon, return only the text before the semicolon
    """
    if "; " in item:
        new_item = item.split("; ")[0]
        # print("Changed ", item, " to ", new_item)
        return new_item
    return item


def get_str_after_apostrophe(item):
    """
    Checks it the language is FR or IT and returns the string after the apostrophe,
    this is to exclude words like " l' " or " d' " in French and Italian
    """
    if "'" in item and (language == 'italian' or language == 'french'):
        new_item = item.split("'")[1]
        # print(f'Changed "{item}"  to  "{new_item}"')
        return new_item
    return item

# %% [markdown]
# We iterate over the languages list to run the task for each prepared document in all languages.
# The files should be in the following formats:
# `'./FreqWordLists/{language}_WordList.tsv'`   and    `'./TargetItemLists/{language}_TargetItems.tsv'`

# %%
# We can iterate over the languages list to run the task for each prepared document in all languages
# The files should be in the following formats:
# '{language}_WordList.tsv'   and    '{language}_TargetItems.tsv'
languages = ['italian',
             'english',
             'spanish',
             'french',
             'german',
             'russian',
             'korean',
             'japanese']

for lang in languages:
    create_new_list_file(lang)
# Out:
# -------------
# ITALIAN
# Found 6035 unmatched words in Italian from the list of 7591 words
#
# Removed 1556 words from the word list
# >> 241 were stopwords:
#     ['non', 'di', 'che', 'e', 'la', 'il', 'un', 'a', 'per', 'in', 'una', 'mi', 'ma', 'lo', 'le', 'si', 'ti', 'i', 'con', 'se', 'io', 'come', 'da', 'ci', 'questo', 'tu', 'più', 'mio', 'lei', 'gli', 'tutto', 'mia', 'ne', 'questa', 'chi', 'o', 'anche', 'quello', 'lui', 'suo', 'dove', 'uno', 'tuo', 'noi', 'su', 'vi', 'loro', 'voi', 'quanto', 'cui', 'tra', 'nostro', 'nostra', 'vostro', 'quale', 'quelli', 'contro', 'quella', 'sua', 'del', 'negli', 'quante', 'nello', 'coi', 'è', 'sono', 'ho', 'ha', 'hai', 'sei', 'al', 'era', 'della', 'alla', 'abbiamo', 'tutti', 'dei', 'sta', 'perché', 'sia', 'nel', 'tua', 'siamo', 'hanno', 'stai', 'delle', 'sto', 'ad', 'nella', 'sul', 'ed', 'fai', 'dai', 'dal', 'sarebbe', 'dalla', 'fosse', 'avete', 'sulla', 'miei', 'alle', 'facendo', 'abbia', 'ero', 'aveva', 'questi', 'siete', 'ai', 'avevo', 'degli', 'queste', 'faccio', 'avuto', 'faccia', 'sarà', 'tuoi', 'suoi', 'stiamo', 'erano', 'avrei', 'avrebbe', 'stanno', 'stavo', 'facciamo', 'nei', 'quelle', 'mie', 'nostri', 'col', 'vostra', 'sue', 'nelle', 'stava', 'eri', 'fanno', 'fossi', 'stia', 'tue', 'avessi', 'avevi', 'siano', 'avresti', 'sarei', 'farò', 'dalle', 'quanti', 'saranno', 'faremo', 'fu', 'agli', 'sulle', 'avesse', 'nostre', 'eravamo', 'sui', 'farai', 'sarai', 'dello', 'allo', 'vostri', 'faceva', 'farà', 'avrai', 'saresti', 'sarò', 'avevamo', 'avevano', 'stessi', 'saremo', 'stavi', 'fossero', 'stesse', 'farebbe', 'avremmo', 'vostre', 'avremo', 'dagli', 'stavamo', 'avrà', 'avrebbero', 'farei', 'l', 'abbiano', 'sarebbero', 'faranno', 'saremmo', 'stavano', 'faresti', 'siate', 'avrò', 'facevo', 'eravate', 'fece', 'dallo', 'abbiate', 'sugli', 'fossimo', 'starai', 'sarete', 'avranno', 'avessero', 'avessimo', 'avrete', 'facevi', 'facessi', 'sullo', 'avendo', 'facesse', 'farete', 'furono', 'all', 'starà', 'stiano', 'facevano', 'avreste', 'avevate', 'quanta', 'staremo', 'facciano', 'foste', 'stavate', 'starò', 'dell', 'facevamo', 'stando', 'feci', 'sareste', 'essendo', 'avuta', 'aveste', 'farebbero', 'ebbe', 'staranno', 'stiate', 'nell', 'fui', 'starei', 'starebbe', 'stessero', 'fecero', 'li']
#
# >> 1315 already exist in CAS:
#     ['essere', 'cosa', 'no', 'qui', 'bene', 'sì', 'me', 'solo', 'te', 'così', 'fare', 'ora', 'mai', 'molto', 'andare', 'niente', 'grazie', 'stato', 'potere', 'prima', 'allora', 'due', 'ancora', 'vero', 'casa', 'sempre', 'forse', 'altro', 'vita', 'tempo', 'certo', 'poi', 'uomo', 'signore', 'credere', 'già', 'anno', 'vedere', 'fuori', 'davvero', 'volta', 'via', 'dopo', 'senza', 'meglio', 'ciao', 'lavorare', 'ogni', 'troppo', 'posto', 'male', 'venire', 'amico', 'tre', 'momento', 'prego', 'parlare', 'guardare', 'signora', 'grande', 'lì', 'successo', 'donna', 'nuovo', 'forza', 'bello', 'soldi', 'favore', 'dentro', 'oggi', 'accordo', 'notte', 'figlio', 'mondo', 'aspettare', 'amore', 'moglie', 'sicuro', 'pensare', 'paura', 'idea', 'testa', 'papà', 'giusto', 'sentire', 'presto', 'basta', 'stesso', 'porta', 'buono', 'quindi', 'appena', 'ragazzo', 'domani', 'insieme', 'sotto', 'capire', 'morto', 'letto', 'storia', 'caso', 'trovare', 'problema', 'tipo', 'terra', 'dare', 'secondo', 'film', 'mano', 'prendere', 'meno', 'città', 'fine', 'tesoro', 'primo', 'nave', 'sera', 'piano', 'macchina', 'dottore', 'tardi', 'cuore', 'famiglia', 'aiutare', 'diavolo', 'quasi', 'polizia', 'capo', 'sperare', 'guerra', 'bambino', 'strada', 'vecchio', 'fratello', 'acqua', 'stasera', 'chiamare', 'marito', 'minuto', 'ricordare', 'nemmeno', 'punto', 'invece', 'perdere', 'possibile', 'uccidere', 'cercare', 'verità', 're', 'importante', 'amare', 'chiedere', 'felice', 'piede', 'piccolo', 'dietro', 'buongiorno', 'passare', 'dollaro', 'cinque', 'vicino', 'uscire', 'conoscere', 'verso', 'quattro', 'morire', 'almeno', 'lasciare', 'vivere', 'portare', 'entrare', 'pace', 'migliore', 'difficile', 'settimana', 'ultimo', 'fatta', 'stanza', 'comunque', 'numero', 'mente', 'strano', 'parola', 'vista', 'finché', 'mese', 'fuoco', 'serio', 'paese', 'mezzo', 'prova', 'caro', 'cane', 'senso', 'riuscire', 'ieri', 'scuola', 'resto', 'bere', 'cena', 'giovane', 'ascoltare', 'corpo', 'musica', 'gioco', 'aria', 'davanti', 'domanda', 'campo', 'paio', 'cielo', 'auto', 'sorella', 'festa', 'affare', 'facile', 'restare', 'attenzione', 'controllo', 'generale', 'ragazza', 'scrivere', 'tenere', 'ufficio', 'dieci', 'trattare', 'pistola', 'voce', 'dormire', 'chiaro', 'squadra', 'ordine', 'arrivare', 'ormai', 'maggiore', 'fretta', 'sacco', 'fatto', 'situazione', 'decidere', 'esattamente', 'inglese', 'perfetto', 'alto', 'pazzo', 'capelli', 'morte', 'fantastico', 'matrimonio', 'passo', 'diventare', 'bagno', 'zio', 'futuro', 'sbagliato', 'sicurezza', 'pezzo', 'silenzio', 'giocare', 'lontano', 'segreto', 'sole', 'mettere', 'sistema', 'viaggio', 'causa', 'semplice', 'presidente', 'bocca', 'permesso', 'sogno', 'probabilmente', 'fame', 'cura', 'prigione', 'finire', 'buonanotte', 'prossimo', 'specie', 'circa', 'funzionare', 'brutto', 'peccato', 'mattina', 'consiglio', 'cambiare', 'usare', 'continuare', 'possibilità', 'spesso', 'piuttosto', 'fondo', 'ospedale', 'leggere', 'agire', 'servizio', 'messaggio', 'energia', 'incredibile', 'mandare', 'aereo', 'ricevere', 'preoccuparti', 'finalmente', 'mostro', 'sette', 'programma', 'partita', 'gentile', 'freddo', 'genitori', 'solito', 'terribile', 'buonasera', 'oro', 'occhio', 'radio', 'pieno', 'provare', 'scoprire', 'interessante', 'avvocato', 'ottimo', 'esercito', 'vestiti', 'treno', 'cibo', 'tempi', 'laggiù', 'intorno', 'servire', 'chiave', 'diritto', 'cinema', 'ritardo', 'realtà', 'mare', 'pianeta', 'fronte', 'assolutamente', 'risposta', 'rispetto', 'pena', 'occhiata', 'sorpresa', 'salute', 'lettera', 'incidente', 'grosso', 'sembrare', 'sinistra', 'contento', 'canzone', 'speciale', 'gruppo', 'giurare', 'so', 'va', 'posso', 'fa', 'credo', 'anni', 'andiamo', 'visto', 'lavoro', 'bisogno', 'dispiace', 'penso', 'mamma', 'vai', 'sa', 'aspetta', 'piace', 'vieni', 'guarda', 'tutte', 'capito', 'volte', 'vado', 'scusa', 'dici', 'capisco', 'aiuto', 'dovrei', 'dovresti', 'ore', 'passato', 'perso', 'scusi', 'potrei', 'importa', 'amo', 'agente', 'foto', 'andando', 'divertente' ...
# -------------
# ENGLISH
# Found 3007 unmatched words in English from the list of 5000 words
#
# Removed 1993 words from the word list
# >> 163 were stopwords:
#     ['the', 'be', 'and', 'of', 'a', 'in', 'to', 'have', 'to', 'it', 'that', 'for', 'you', 'he', 'with', 'on', 'do', 's', 'they', 'this', 'but', 'at', 'we', 'his', 'from', 'that', 'not', 'by', 'or', 'she', 'as', 'what', 'their', 'will', 'who', 'can', 'if', 'all', 'her', 'about', 'my', 'as', 'there', 'up', 'so', 'which', 'when', 'some', 'them', 'me', 'out', 'into', 'just', 'him', 'your', 'now', 'than', 'other', 'then', 'how', 'its', 'our', 'more', 'these', 'no', 'because', 'more', 'here', 'only', 'those', 'very', 'her', 'any', 'through', 'there', 'down', 'after', 'over', 'should', 'in', 'as', 'too', 'when', 'between', 'most', 'own', 'out', 'on', 'while', 'why', 'same', 'where', 'against', 'about', 'over', 'such', 'again', 'most', 'few', 'where', 'each', 'so', 'during', 'off', 'before', 'all', 'under', 'both', 'after', 'no', 'until', 'once', 'only', 'such', 'himself', 'before', 'both', 'off', 'themselves', 'up', 'because', 'itself', 'no', 'myself', 'before', 'than', 'other', 'each', 'no', 'herself', 'above', 'that', 'yourself', 'whom', 'down', 'nor', 'own', 'by', 'once', 'very', 'through', 'until', 'below', 'above', 'under', 'being', 'but', 'ourselves', 'just', 'now', 'his', 'below', 'for', 'other', 'not', 'in', 'can', 'yours', 'no', 'hers', 'ours', 'this', 'any']
#
# >> 1830 already exist in CAS:
#     ['I', 'say', 'go', 'get', 'would', 'make', 'know', 'one', 'time', 'year', 'think', 'see', 'people', 'take', 'come', 'like', 'two', 'want', 'way', 'look', 'first', 'also', 'new', 'day', 'use', 'man', 'find', 'give', 'thing', 'well', 'many', 'tell', 'one', 'even', 'back', 'good', 'us', 'woman', 'life', 'child', 'work', 'call', 'may', 'world', 'still', 'try', 'school', 'last', 'ask', 'need', 'three', 'feel', 'become', 'state', 'never', 'high', 'something', 'really', 'another', 'much', 'family', 'house', 'leave', 'put', 'old', 'mean', 'president', 'keep', 'great', 'begin', 'big', 'seem', 'group', 'country', 'talk', 'problem', 'turn', 'student', 'every', 'hand', 'help', 'start', 'American', 'part', 'show', 'might', 'place', 'city', 'case', 'system', 'week', 'company', 'percent', 'hear', 'question', 'right', 'program', 'work', 'run', 'number', 'small', 'government', 'play', 'move', 'like', 'always', 'night', 'believe', 'today', 'hold', 'point', 'live', 'happen', 'bring', 'next', 'without', 'large', 'must', 'war', 'home', 'room', 'fact', 'area', 'national', 'write', 'money', 'right', 'story', 'water', 'different', 'young', 'month', 'lot', 'book', 'eye', 'study', 'job', 'kind', 'word', 'issue', 'side', 'four', 'business', 'head', 'long', 'black', 'million', 'little', 'since', 'around', 'long', 'provide', 'service', 'important', 'sit', 'away', 'friend', 'however', 'power', 'yet', 'hour', 'often', 'political', 'line', 'end', 'stand', 'game', 'ever', 'lose', 'bad', 'member', 'meet', 'pay', 'law', 'almost', 'car', 'much', 'name', 'five', 'center', 'university', 'continue', 'least', 'white', 'change', 'set', 'ago', 'information', 'nothing', 'community', 'best', 'right', 'idea', 'lead', 'body', 'learn', 'kid', 'minute', 'table', 'understand', 'team', 'back', 'watch', 'together', 'follow', 'around', 'stop', 'face', 'anything', 'public', 'social', 'already', 'parent', 'speak', 'create', 'office', 'allow', 'level', 'read', 'spend', 'person', 'door', 'sure', 'add', 'street', 'history', 'party', 'grow', 'reason', 'morning', 'open', 'change', 'walk', 'news', 'health', 'court', 'force', 'early', 'low', 'art', 'result', 'moment', 'offer', 'remember', 'research', 'enough', 'girl', 'boy', 'win', 'food', 'guy', 'second', 'able', 'maybe', 'process', 'everything', 'appear', 'age', 'policy', 'consider', 'probably', 'education', 'love', 'actually', 'buy', 'wait', 'die', 'human', 'send', 'expect', 'serve', 'sense', 'teacher', 'home', 'market', 'stay', 'build', 'nation', 'fall', 'oh', 'death', 'plan', 'someone', 'experience', 'cut', 'kill', 'behind', 'reach', 'six', 'local', 'remain', 'effect', 'suggest', 'use', 'control', 'perhaps', 'raise', 'class', 'late', 'little', 'else', 'pass', 'photo', 'sell', 'field', 'sometimes', 'require', 'decide', 'security', 'possible', 'effort', 'role', 'better', 'rate', 'strong', 'music', 'report', 'leader', 'light', 'whole', 'voice', 'color', 'heart', 'care', 'police', 'economic', 'wife', 'show', 'mind', 'report', 'finally', 'less', 'return', 'pull', 'decision', 'explain', 'carry', 'develop', 'view', 'free', 'hope', 'even', 'drive', 'son', 'arm', 'department', 'TRUE', 'price', 'military', 'federal', 'break', 'action', 'value', 'thank', 'relationship', 'town', 'better', 'building', 'receive', 'society', 'difference', 'church', 'full', 'join', 'road', 'international', 'model', 'position', 'early', 'agree', 'matter', 'especially', 'form', 'record', 'special', 'ground', 'whose', 'hard', 'pick', 'paper', 'official', 'season', 'wear', 'support', 'player', 'everyone', 'couple', 'end', 'base', 'project', 'produce', 'situation', 'hit', 'industry', 'half', 'activity', 'American', 'eat', 'need', 'figure', 'cost', 'easy', 'quite', 'face', 'picture', 'clear', 'cover', 'describe', 'image', 'teach', 'wall', 'doctor', 'product', 'data', 'practice', 'phone', 'piece', 'certain', 'either', 'oil', 'simply', 'test', 'personal', 'star', 'land', 'third', 'general', 'computer', 'movie', 'worker', 'open', 'catch', 'type', 'support', 'north', 'l ...
# -------------
# SPANISH
# Found 3512 unmatched words in Spanish from the list of 5000 words
#
# Removed 1488 words from the word list
# >> 75 were stopwords:
#     ['de', 'que', 'y', 'en', 'un', 'a', 'él', 'lo', 'no', 'su', 'con', 'por', 'para', 'mí', 'lo', 'como', 'estar', 'me', 'más', 'este', 'le', 'se', 'yo', 'o', 'pero', 'ese', 'otro', 'mi', 'ya', 'porque', 'mucho', 'muy', 'sí', 'ti', 'te', 'también', 'qué', 'nos', 'tu', 'sin', 'eso', 'cuando', 'hasta', 'la', 'sobre', 'entre', 'desde', 'ella', 'poco', 'nuestro', 'ni', 'donde', 'nada', 'tanto', 'algo', 'esto', 'quien', 'durante', 'cual', 'nosotros', 'contra', 'tú', 'antes', 'ante', 'estado', 'fuera', 'sentido', 'uno', 'todo', 'mío', 'os', 'suyo', 'tuyo', 'vuestro', 'vosotros']
#
# >> 1413 already exist in CAS:
#     ['ser', 'tener', 'hacer', 'decir', 'poder', 'ir', 'si', 'dar', 'saber', 'año', 'mismo', 'querer', 'vez', 'dos', 'día', 'grande', 'así', 'pasar', 'deber', 'entonces', 'llegar', 'bien', 'tiempo', 'ahora', 'primero', 'creer', 'vida', 'dejar', 'parecer', 'hablar', 'poner', 'parte', 'nuevo', 'siempre', 'hombre', 'seguir', 'quedar', 'llevar', 'encontrar', 'tan', 'pensar', 'casa', 'persona', 'país', 'volver', 'salir', 'después', 'mejor', 'menos', 'venir', 'forma', 'mujer', 'momento', 'llamar', 'mundo', 'claro', 'mirar', 'conocer', 'aquí', 'aunque', 'tomar', 'tres', 'mano', 'sentir', 'gente', 'cuándo', 'hijo', 'tratar', 'vivir', 'lugar', 'problema', 'hacia', 'presidente', 'junto', 'luego', 'cómo', 'trabajo', 'caso', 'mayor', 'además', 'esperar', 'nunca', 'cierto', 'hora', 'dónde', 'padre', 'gustar', 'noche', 'casi', 'hoy', 'tipo', 'ojo', 'manera', 'importante', 'contar', 'niño', 'trabajar', 'empezar', 'verdad', 'ciudad', 'buscar', 'solo', 'fin', 'gobierno', 'historia', 'ejemplo', 'último', 'punto', 'mil', 'palabra', 'obra', 'existir', 'perder', 'cuenta', 'allí', 'escribir', 'grupo', 'señor', 'pequeño', 'embargo', 'nadie', 'entrar', 'arte', 'leer', 'amigo', 'recordar', 'morir', 'único', 'lado', 'nombre', 'recibir', 'pedir', 'permitir', 'preguntar', 'social', 'sistema', 'tal', 'segundo', 'viejo', 'madre', 'siglo', 'nacional', 'entender', 'libro', 'alto', 'cuerpo', 'familia', 'presentar', 'bajo', 'frente', 'crear', 'tema', 'cuatro', 'humano', 'pueblo', 'producir', 'abrir', 'idea', 'millón', 'aún', 'caer', 'voz', 'terminar', 'oír', 'cambiar', 'considerar', 'político', 'español', 'igual', 'todavía', 'cabeza', 'derecho', 'mantener', 'calle', 'relación', 'puerta', 'necesitar', 'luz', 'paso', 'general', 'escuchar', 'guerra', 'amor', 'cinco', 'situación', 'conseguir', 'lograr', 'quién', 'ocurrir', 'aparecer', 'diferente', 'muerte', 'ganar', 'estudio', 'nivel', 'proceso', 'semana', 'partido', 'acabar', 'explicar', 'cuyo', 'razón', 'negro', 'bastante', 'efecto', 'servicio', 'formar', 'económico', 'servir', 'empresa', 'centro', 'usar', 'tras', 'cambio', 'clase', 'hecho', 'dicho', 'información', 'tocar', 'ayudar', 'público', 'mostrar', 'estudiar', 'hermano', 'ley', 'incluso', 'cara', 'programa', 'música', 'traer', 'campo', 'correr', 'actividad', 'quizás', 'alguien', 'comer', 'acuerdo', 'demás', 'siguiente', 'ofrecer', 'poder', 'sociedad', 'levantar', 'dios', 'jugar', 'zona', 'malo', 'comprar', 'necesario', 'camino', 'dinero', 'pie', 'final', 'tampoco', 'decidir', 'desarrollo', 'movimiento', 'alcanzar', 'blanco', 'equipo', 'difícil', 'desarrollar', 'pronto', 'pagar', 'proyecto', 'meter', 'realmente', 'sol', 'imagen', 'varios', 'universidad', 'interés', 'mayoría', 'tarde', 'papel', 'producto', 'medio', 'rico', 'ojalá', 'reconocer', 'mañana', 'dormir', 'pesar', 'seguro', 'vista', 'subir', 'intentar', 'personal', 'fondo', 'descubrir', 'olvidar', 'experiencia', 'incluir', 'condición', 'edad', 'andar', 'joven', 'escuela', 'nacer', 'posible', 'aprender', 'serie', 'suponer', 'aceptar', 'fuerte', 'especial', 'iglesia', 'seis', 'falta', 'política', 'especie', 'cuál', 'diez', 'tercero', 'espacio', 'bajo', 'publicar', 'población', 'tarde', 'artículo', 'cantidad', 'sueño', 'echar', 'internacional', 'responder', 'boca', 'próximo', 'mover', 'menor', 'cultura', 'brazo', 'uso', 'ser', 'corazón', 'sitio', 'minuto', 'señalar', 'mar', 'carrera', 'base', 'bajar', 'mercado', 'respuesta', 'atención', 'educación', 'miedo', 'pobre', 'anterior', 'demasiado', 'evitar', 'río', 'actual', 'imaginar', 'profesor', 'resultado', 'sufrir', 'pregunta', 'señora', 'representar', 'investigación', 'repetir', 'favor', 'viaje', 'cerrar', 'resto', 'comunidad', 'faltar', 'mesa', 'indicar', 'vender', 'supuesto', 'libertad', 'organización', 'peso', 'diferencia', 'rojo', 'seguridad', 'cuestión', 'miembro', 'desear', 'película', 'región', 'dentro', 'suelo', 'paz', 'precio', 'verdadero', 'soler', 'crecer', 'elegir', 'francés', 'demostrar', 'oportunidad', 'conocimiento', 'producción', 'objeto ...
# -------------
# FRENCH
# Found 3589 unmatched words in French from the list of 5000 words
#
# Removed 1411 words from the word list
# >> 43 were stopwords:
#     ['le', 'de', 'un', 'à', 'et', 'en', 'que', 'pour', 'dans', 'ce', 'il', 'qui', 'ne', 'sur', 'se', 'pas', 'par', 'je', 'avec', 'son', 'on', 'mais', 'nous', 'ou', 'leur', 'y', 'elle', 'même', 'vous', 'mon', 'me', 'lui', 'notre', 'tu', 'moi', 'eux', 'soit', 'te', 'votre', 'ton', 'toi', 'été', 'est']
#
# >> 1368 already exist in CAS:
#     ['être', 'avoir', 'plus', 'pouvoir', 'tout', 'faire', 'mettre', 'autre', 'si', 'dire', 'devoir', 'avant', 'deux', 'prendre', 'aussi', 'donner', 'bien', 'où', 'fois', 'encore', 'nouveau', 'aller', 'entre', 'premier', 'déjà', 'grand', 'moins', 'aucun', 'temps', 'très', 'savoir', 'voir', 'sans', 'raison', 'dont', 'non', 'monde', 'jour', 'demander', 'alors', 'après', 'trouver', 'personne', 'rendre', 'dernier', 'venir', 'pendant', 'passer', 'peu', 'bon', 'depuis', 'point', 'heure', 'rester', 'seul', 'année', 'toujours', 'tenir', 'porter', 'parler', 'montrer', 'là', 'certain', 'fin', 'continuer', 'pays', 'trois', 'partie', 'quand', 'suivre', 'contre', 'sous', 'côté', 'ensemble', 'chose', 'enfant', 'cause', 'politique', 'place', 'seulement', 'vie', 'connaître', 'croire', 'homme', 'petit', 'commencer', 'compter', 'fait', 'droit', 'question', 'général', 'moment', 'entendre', 'beaucoup', 'chaque', 'jeune', 'travail', 'femme', 'attendre', 'appeler', 'permettre', 'occuper', 'gouvernement', 'devenir', 'partir', 'plan', 'décider', 'ici', 'rien', 'affaire', 'nom', 'famille', 'effet', 'arriver', 'possible', 'servir', 'mois', 'jamais', 'sembler', 'vers', 'besoin', 'revenir', 'moyen', 'groupe', 'problème', 'rapport', 'vue', 'maintenant', 'pourquoi', 'meilleur', 'trop', 'laisser', 'ordre', 'devant', 'recevoir', 'répondre', 'vivre', 'service', 'ministre', 'face', 'chez', 'rappeler', 'présenter', 'accepter', 'agir', 'simple', 'important', 'présent', 'mieux', 'poser', 'jouer', 'mot', 'reconnaître', 'situation', 'près', 'choisir', 'national', 'projet', 'toucher', 'train', 'comment', 'surtout', 'gens', 'propre', 'grâce', 'idée', 'région', 'aimer', 'sens', 'retrouver', 'semaine', 'façon', 'perdre', 'français', 'expliquer', 'quatre', 'compte', 'ouvrir', 'gagner', 'exemple', 'ville', 'économique', 'mesure', 'histoire', 'haut', 'ensuite', 'guerre', 'loi', 'président', 'exister', 'sûr', 'refuser', 'plutôt', 'bureau', 'mauvais', 'mort', 'mal', 'lire', 'réussir', 'condition', 'international', 'changer', 'oui', 'public', 'humain', 'souvent', 'cinq', 'système', 'travailler', 'jeu', 'vrai', 'représenter', 'société', 'difficile', 'quoi', 'entreprise', 'coup', 'or', 'social', 'essayer', 'juste', 'étranger', 'empêcher', 'million', 'sortir', 'prix', 'longtemps', 'intérêt', 'information', 'détail', 'appartenir', 'liberté', 'assez', 'concerner', 'maison', 'apprendre', 'niveau', 'rencontrer', 'créer', 'état', 'chercher', 'entrer', 'proposer', 'apporter', 'programme', 'loin', 'ligne', 'tête', 'libre', 'utiliser', 'atteindre', 'tenter', 'tard', 'enfin', 'différent', 'cependant', 'importer', 'action', 'relation', 'recherche', 'livre', 'vraiment', 'reste', 'produire', 'préparer', 'forme', 'décision', 'rôle', 'dix', 'produit', 'peuple', 'prochain', 'particulier', 'écrire', 'développement', 'chef', 'économie', 'effort', 'membre', 'tirer', 'beau', 'plein', 'juger', 'éviter', 'soir', 'personnel', 'objet', 'souhaiter', 'réaliser', 'parfois', 'sérieux', 'aider', 'voix', 'terminer', 'base', 'espérer', 'main', 'gros', 'arrêter', 'retour', 'regarder', 'deuxième', 'résultat', 'écouter', 'dollar', 'intérieur', 'confiance', 'choix', 'type', 'but', 'matin', 'prise', 'européen', 'étude', 'six', 'nécessaire', 'activité', 'marquer', 'entier', 'réponse', 'pourtant', 'maintenir', 'époque', 'ami', 'bas', 'moitié', 'argent', 'œil', 'eau', 'école', 'sécurité', 'milieu', 'lettre', 'presque', 'attention', 'futur', 'mouvement', 'former', 'conduire', 'règle', 'poste', 'centre', 'acte', 'accord', 'passé', 'déclarer', 'oublier', 'troisième', 'quitter', 'bout', 'population', 'route', 'tôt', 'limite', 'objectif', 'journal', 'annoncer', 'voilà', 'volonté', 'envoyer', 'partager', 'établir', 'changement', 'garder', 'réalité', 'finir', 'sentir', 'esprit', 'nature', 'tomber', 'mondial', 'entraîner', 'faux', 'genre', 'communauté', 'intéresser', 'corps', 'difficulté', 'parvenir', 'appel', 'cœur', 'père', 'organisation', 'unité', 'noir', 'événement', 'nation', 'conseil', 'soutenir', 'paix', 'nuit', 'par ...
# -------------
# GERMAN
# Found 3430 unmatched words in German from the list of 5009 words
#
# Removed 1579 words from the word list
# >> 109 were stopwords:
#     ['der', 'und', 'in', 'sein', 'ein', 'haben', 'sie', 'werden', 'von', 'ich', 'nicht', 'es', 'mit', 'sich', 'er', 'auf', 'für', 'auch', 'an', 'dass', 'zu', 'als', 'können', 'dies', 'wie', 'wir', 'ihr', 'so', 'bei', 'sein', 'aber', 'man', 'noch', 'nach', 'oder', 'aus', 'was', 'nur', 'dann', 'wenn', 'um', 'kein', 'über', 'da', 'vor', 'mein', 'du', 'durch', 'viel', 'wollen', 'machen', 'andere', 'mir', 'mich', 'hier', 'also', 'jetzt', 'doch', 'wieder', 'uns', 'bis', 'einer', 'sehr', 'unser', 'jede', 'weil', 'unter', 'ihm', 'ihn', 'denn', 'etwas', 'selbst', 'gegen', 'zwischen', 'wo', 'nichts', 'nun', 'sondern', 'damit', 'ohne', 'einmal', 'ihnen', 'ob', 'dort', 'dazu', 'während', 'einige', 'zwar', 'meinen', 'dich', 'weiter', 'dein', 'dir', 'hinter', 'anders', 'dessen', 'sonst', 'damit', 'jene', 'manche', 'euch', 'am', 'derselbe', 'indem', 'hin', 'weg', 'euer', 'einigen', 'einig']
#
# >> 1470 already exist in CAS:
#     ['müssen', 'ja', 'geben', 'mehr', 'Jahr', 'sollen', 'schon', 'kommen', 'immer', 'gehen', 'groß', 'ganz', 'zwei', 'gut', 'wissen', 'sehen', 'Mal', 'lassen', 'neu', 'stehen', 'Mensch', 'Beispiel', 'erste', 'Zeit', 'lang', 'leben', 'Frau', 'wenig', 'finden', 'drei', 'liegen', 'klein', 'Tag', 'bleiben', 'heute', 'beide', 'Mann', 'tun', 'denken', 'seit', 'einfach', 'Kind', 'Land', 'stellen', 'zeigen', 'natürlich', 'alt', 'Deutschland', 'gleich', 'nehmen', 'dürfen', 'wichtig', 'vielleicht', 'hören', 'nein', 'wer', 'letzte', 'fragen', 'Herr', 'halten', 'glauben', 'Frage', 'gerade', 'folgen', 'führen', 'bringen', 'Welt', 'gar', 'genau', 'mögen', 'spät', 'möglich', 'Prozent', 'kurz', 'richtig', 'brauchen', 'Hand', 'etwa', 'Ende', 'schreiben', 'nie', 'Fall', 'schön', 'wirklich', 'nennen', 'warum', 'ziehen', 'Wort', 'darauf', 'Seite', 'Teil', 'jung', 'vier', 'besser', 'fast', 'schnell', 'Stadt', 'spielen', 'Euro', 'Arbeit', 'Problem', 'verstehen', 'bekommen', 'davon', 'fahren', 'kennen', 'Mutter', 'Woche', 'Weg', 'Auge', 'oft', 'sogar', 'setzen', 'deshalb', 'weit', 'sitzen', 'Vater', 'arbeiten', 'Geld', 'nächste', 'erklären', 'klar', 'Paar', 'Wasser', 'bestehen', 'versuchen', 'Punkt', 'Grund', 'Kopf', 'beginnen', 'laufen', 'Bild', 'Aufgabe', 'schwer', 'treffen', 'Geschichte', 'erzählen', 'sicher', 'neben', 'allein', 'besonders', 'tragen', 'kaum', 'Freund', 'fünf', 'scheinen', 'Stunde', 'aussehen', 'gern', 'überhaupt', 'bestimmt', 'Professor', 'schaffen', 'damals', 'erhalten', 'lernen', 'frei', 'Wert', 'suchen', 'Europa', 'gemeinsam', 'Thema', 'Buch', 'bisschen', 'politisch', 'lesen', 'Blick', 'leicht', 'verlieren', 'beste', 'Monat', 'Sache', 'Ziel', 'essen', 'Minute', 'Nacht', 'Platz', 'schlecht', 'Spiel', 'jemand', 'zehn', 'Preis', 'europäisch', 'Staat', 'helfen', 'Abend', 'Stelle', 'unterschiedlich', 'Gesicht', 'Entwicklung', 'schließen', 'direkt', 'offen', 'erkennen', 'Person', 'Moment', 'Schule', 'Auto', 'niemand', 'Gesellschaft', 'warten', 'vorstellen', 'treten', 'reden', 'Gruppe', 'Ding', 'na', 'gewinnen', 'Tür', 'Schritt', 'entwickeln', 'Sinn', 'passieren', 'manchmal', 'System', 'Rolle', 'Ergebnis', 'vergleichen', 'voll', 'erwarten', 'obwohl', 'Straße', 'Angst', 'allgemein', 'erinnern', 'Stimme', 'wirken', 'Raum', 'Eltern', 'erscheinen', 'früher', 'pro', 'entscheiden', 'Universität', 'betreffen', 'oben', 'Richtung', 'fehlen', 'Sprache', 'Produkt', 'außerdem', 'international', 'Anfang', 'sechs', 'sozial', 'Folge', 'Satz', 'beschreiben', 'Licht', 'ähnlich', 'gegenüber', 'Kollege', 'halb', 'lachen', 'sofort', 'Grenze', 'ändern', 'Entscheidung', 'verlassen', 'endlich', 'Energie', 'plötzlich', 'danach', 'lieber', 'gehören', 'Gefühl', 'trotzdem', 'Information', 'Weise', 'Zukunft', 'wachsen', 'bitte', 'weiß', 'schwarz', 'sterben', 'rot', 'Meter', 'Hilfe', 'ausgehen', 'Chemie', 'Luft', 'Körper', 'Struktur', 'Jahrhundert', 'wahrscheinlich', 'öffentlich', 'anfangen', 'Wohnung', 'bald', 'Film', 'kaufen', 'ansehen', 'öffnen', 'Musik', 'Stück', 'tot', 'positiv', 'Gespräch', 'Kunde', 'Menge', 'Regierung', 'Antwort', 'annehmen', 'falsch', 'langsam', 'Arm', 'Tisch', 'rufen', 'Herz', 'zusammen', 'Boden', 'Politik', 'Tod', 'Erfolg', 'ab', 'persönlich', 'Präsident', 'holen', 'Junge', 'Polizei', 'Chance', 'Kunst', 'Schüler', 'Druck', 'wohnen', 'bewegen', 'enthalten', 'Kosten', 'laut', 'Fuß', 'Daten', 'Krieg', 'Gast', 'Gesetz', 'planen', 'schwierig', 'Kilometer', 'vergessen', 'Gedanke', 'ach', 'freuen', 'hängen', 'Zelle', 'eng', 'Kultur', 'Prozess', 'Sohn', 'studieren', 'gefallen', 'Mädchen', 'mindestens', 'ziemlich', 'Interesse', 'reichen', 'sieben', 'Tier', 'erhöhen', 'Erfahrung', 'Patient', 'Morgen', 'Arzt', 'lösen', 'anbieten', 'okay', 'wünschen', 'interessieren', 'Unterschied', 'Foto', 'trinken', 'Mitarbeiter', 'Glück', 'normal', 'leider', 'acht', 'Leistung', 'Beziehung', 'zunehmen', 'ankommen', 'auftreten', 'wann', 'los', 'Bett', 'Zimmer', 'bauen', 'selten', 'Zeitung', 'Bedingung', 'Fenster', 'Zug', 'schlafen', 'statt', 'grün', 'Bürger', 'di ...
# -------------
# RUSSIAN
# Found 3494 unmatched words in Russian from the list of 5000 words
#
# Removed 1506 words from the word list
# >> 111 were stopwords:
#     ['и', 'в', 'не', 'на', 'я', 'быть', 'с', 'он', 'что', 'а', 'этот', 'по', 'к', 'но', 'они', 'мы', 'она', 'как', 'то', 'из', 'у', 'вы', 'за', 'для', 'от', 'так', 'ты', 'о', 'что', 'же', 'такой', 'тот', 'или', 'если', 'только', 'его', 'один', 'бы', 'себя', 'другой', 'уже', 'когда', 'до', 'мой', 'чтобы', 'вот', 'кто', 'при', 'можно', 'сам', 'два', 'даже', 'раз', 'их', 'какой', 'со', 'там', 'после', 'ли', 'где', 'под', 'нет', 'без', 'ну', 'более', 'чем', 'надо', 'здесь', 'потом', 'да', 'сейчас', 'через', 'много', 'теперь', 'ни', 'тогда', 'тут', 'тоже', 'всегда', 'между', 'конечно', 'три', 'перед', 'над', 'хорошо', 'больше', 'почти', 'ведь', 'никогда', 'совсем', 'про', 'вдруг', 'нельзя', 'опять', 'наконец', 'куда', 'иногда', 'зачем', 'чуть', 'хоть', 'впрочем', 'лучше', 'всего', 'разве', 'будто', 'может', 'есть', 'чего', 'том', 'ничего', 'себе']
#
# >> 1395 already exist in CAS:
#     ['это', 'который', 'человек', 'год', 'всё', 'время', 'ещё', 'сказать', 'говорить', 'самый', 'знать', 'очень', 'день', 'жизнь', 'первый', 'дело', 'новый', 'хотеть', 'должен', 'работа', 'иметь', 'понимать', 'рука', 'город', 'вопрос', 'её', 'давать', 'слово', 'место', 'каждый', 'ребёнок', 'друг', 'идти', 'большой', 'просто', 'Россия', 'делать', 'мир', 'оставаться', 'думать', 'сторона', 'хороший', 'глаз', 'несколько', 'дом', 'страна', 'работать', 'отвечать', 'последний', 'лицо', 'жить', 'женщина', 'выходить', 'часть', 'также', 'система', 'вид', 'голова', 'конец', 'смотреть', 'проблема', 'принимать', 'спрашивать', 'второй', 'именно', 'поэтому', 'почему', 'Москва', 'любой', 'никто', 'час', 'деньги', 'считать', 'земля', 'сегодня', 'русский', 'вообще', 'взять', 'книга', 'пойти', 'компания', 'история', 'любить', 'возможность', 'всё', 'результат', 'высокий', 'например', 'сидеть', 'уходить', 'машина', 'группа', 'пока', 'находиться', 'право', 'война', 'путь', 'стоять', 'помогать', 'стоить', 'ответ', 'вода', 'язык', 'показывать', 'казаться', 'далеко', 'маленький', 'решение', 'народ', 'рассказывать', 'власть', 'сразу', 'ночь', 'полный', 'никакой', 'главный', 'оно', 'дверь', 'часто', 'уровень', 'создавать', 'закон', 'развитие', 'программа', 'отец', 'нога', 'вместе', 'старый', 'момент', 'помощь', 'цель', 'следующий', 'число', 'тысяча', 'минута', 'информация', 'процесс', 'голос', 'месяц', 'школа', 'качество', 'ситуация', 'область', 'внимание', 'следовать', 'дорога', 'использовать', 'замечать', 'молодой', 'мужчина', 'предлагать', 'снова', 'любовь', 'важный', 'ждать', 'игра', 'читать', 'скоро', 'организация', 'статья', 'душа', 'основной', 'тело', 'посмотреть', 'жена', 'открывать', 'пора', 'узнавать', 'письмо', 'общество', 'настоящий', 'вечер', 'существовать', 'назад', 'смысл', 'семья', 'мера', 'государство', 'совершенно', 'вещь', 'простой', 'оставлять', 'утро', 'действительно', 'мать', 'девушка', 'затем', 'вести', 'стол', 'проект', 'улица', 'рынок', 'играть', 'государственный', 'помнить', 'называть', 'точка', 'начинаться', 'тема', 'равный', 'неделя', 'вызывать', 'комната', 'белый', 'центр', 'цена', 'сын', 'идея', 'против', 'правило', 'лучший', 'движение', 'заниматься', 'огромный', 'мама', 'великий', 'количество', 'чувство', 'слишком', 'смерть', 'лежать', 'труд', 'пять', 'получаться', 'достаточно', 'сильный', 'мнение', 'быстро', 'чувствовать', 'третий', 'чёрный', 'пример', 'порядок', 'продолжать', 'век', 'муж', 'речь', 'политический', 'стена', 'ходить', 'окно', 'рядом', 'план', 'тип', 'оба', 'совет', 'современный', 'плохой', 'опыт', 'сердце', 'наука', 'сообщение', 'управление', 'около', 'газета', 'интересный', 'материал', 'роль', 'армия', 'точно', 'четыре', 'долго', 'социальный', 'событие', 'искать', 'большинство', 'правда', 'красный', 'давно', 'правительство', 'бояться', 'суд', 'президент', 'возможно', 'рубль', 'фильм', 'бизнес', 'обычно', 'спать', 'культура', 'носить', 'брать', 'член', 'телефон', 'относиться', 'течение', 'счёт', 'вставать', 'родитель', 'купить', 'разговор', 'метр', 'немного', 'партия', 'образование', 'сколько', 'кстати', 'пара', 'ряд', 'квартира', 'значение', 'желание', 'слушать', 'номер', 'бросать', 'очередь', 'политика', 'класс', 'брат', 'собираться', 'производство', 'район', 'верить', 'факт', 'строить', 'местный', 'определённый', 'небо', 'направление', 'шаг', 'добрый', 'поле', 'исследование', 'пол', 'команда', 'мальчик', 'заставлять', 'метод', 'мало', 'встреча', 'сон', 'служба', 'врач', 'рост', 'ехать', 'нравиться', 'знание', 'население', 'палец', 'десять', 'доллар', 'держать', 'устанавливать', 'дорогой', 'род', 'девочка', 'море', 'природа', 'магазин', 'улыбаться', 'объект', 'память', 'свобода', 'личный', 'плечо', 'музыка', 'самолёт', 'позиция', 'характер', 'размер', 'пить', 'продукт', 'серьёзный', 'солнце', 'сеть', 'лес', 'журнал', 'март', 'национальный', 'искусство', 'участник', 'свободный', 'институт', 'переходить', 'гость', 'международный', 'действовать', 'способный', 'союз', 'песня', 'поздний', 'ум', 'успех', 'парен ...
# -------------
# KOREAN
# Found 3763 unmatched words in Korean from the list of 5000 words
#
# Removed 1237 words from the word list
# >> 0 were stopwords:
#     []
#
# >> 1237 already exist in CAS:
#     ['고', '의', '다', '것', '하다', '그', '있다', '있다', '되다', '가다', '나', '이', '없다', '수', '보다', '말', '사람', '하다', '오다', '구', '우리', '다', '때', '만', '그', '같다', '주다', '안', '아', '보다', '그것', '또', '일', '년', '알다', '내', '지다', '다', '집', '나오다', '살다', '좋다', '받다', '먹다', '말하다', '뭐', '이', '잘', '모르다', '더', '크다', '좀', '뭐', '주다', '소리', '일', '이것', '많다', '들다', '저', '생각하다', '죽다', '여기', '생각', '문제', '듣다', '자기', '고', '얘기', '어떤', '저', '많이', '왜', '돈', '여자', '지금', '어디', '만들다', '들어가다', '개', '보다', '그냥', '다시', '그리고', '자', '오다', '원', '거기', '쓰다', '백', '전', '월', '나가다', '참', '예', '아이', '하나', '다른', '눈', '잡다', '앉다', '들다', '손', '안', '시간', '물', '정도', '만', '한국', '천', '가다', '응', '사회', '치다', '만나다', '어느', '찾다', '사다', '서다', '길', '쓰다', '몇', '네', '같이', '얼굴', '서울', '위', '일본', '마음', '하나', '오늘', '부르다', '나라', '지금', '미국', '너무', '요', '사실', '삼', '남자', '자리', '방', '시', '몸', '통하다', '모두', '후', '두다', '정부', '아들', '제', '분', '보내다', '함께', '시작하다', '친구', '술', '가장', '처음', '이야기', '선생님', '이름', '문', '밤', '관계', '세계', '머리', '내리다', '당신', '이번', '타다', '경제', '인간', '구', '산', '학교', '십', '사이', '생기다', '느끼다', '정말', '다니다', '어렵다', '일어나다', '자', '그러면', '글', '밖', '교육', '맞다', '열다', '밖에', '요', '밥', '대통령', '다르다', '웃다', '입다', '살', '불', '지역', '엄마', '중국', '남', '입', '딸', '둘', '책', '얻다', '열', '시', '해', '니', '문화', '나무', '학생', '기자', '억', '방법', '중요하다', '옷', '오르다', '울다', '특히', '힘', '예', '저녁', '운동', '차', '대학', '땅', '분', '팔다', '이미', '국가', '읽다', '드리다', '요', '일', '끝', '서로', '정치', '새롭다', '높다', '비', '하루', '전화', '떠나다', '과정', '노래', '오', '사랑', '교수', '자', '거의', '이유', '혼자', '아침', '달', '시장', '남편', '사건', '필요하다', '회사', '얼마', '이', '돌다', '멀다', '영화', '쉽다', '작다', '결과', '돌아오다', '떡', '믿다', '정보', '죽이다', '상태', '곧', '결국', '마을', '하늘', '청중', '형', '나가다', '부인', '배우다', '발', '마시다', '할머니', '배', '걸리다', '새', '이르다', '부', '역사', '어리다', '길다', '가슴', '문학', '꿈', '기술', '두다', '삶', '목', '바람', '오빠', '병', '좋아하다', '미', '언니', '이', '계획', '과거', '관심', '달', '사용하다', '요즘', '저희', '꽃', '언어', '입장', '활동', '사진', '지키다', '바꾸다', '변화', '현재', '사업', '현실', '법', '바라다', '자', '환경', '신문', '귀', '아프다', '이루다', '잔', '개혁', '음악', '조금', '갑자기', '장관', '빠지다', '괜찮다', '소', '전혀', '전쟁', '가족', '이십', '사실', '강', '차', '바다', '피', '마지막', '같이', '소설', '다리', '내일', '제도', '그림', '일단', '가능하다', '따다', '지다', '다섯', '손님', '기분', '팔', '참', '사', '네', '거리', '내', '배', '눕다', '선거', '만', '단계', '맞다', '회의', '가르치다', '가능성', '원래', '기관', '병원', '이해하다', '대화', '역할', '산업', '찍다', '잠시', '능력', '차이', '장', '이용하다', '코', '제일', '짜다', '별로', '방향', '벗다', '행동', '육', '벌다', '시민', '가깝다', '컴퓨터', '옮기다', '칼', '과학', '항상', '도시', '금', '세기', '국회', '경찰', '질', '수준', '편지', '수', '음식', '아름답다', '절', '삼십', '개인', '조금', '네', '약', '주장하다', '동', '잊다', '쉬다', '사랑하다', '던지다', '시기', '지나가다', '저', '은행', '싸다', '최고', '자유', '자연', '얘', '늦다', '칠', '일하다', '시험', '가치', '오후', '결혼', '맛', '설명하다', '차다', '기회', '모두', '할아버지', '배', '팀', '물건', '개념', '차례', '개', '언제', '고기', '고향', '피하다', '비슷하다', '외국', '효과', '주', '작가', '약', '움직이다', '장군', '환자', '보통', '새', '태도', '드리다', '죽음', '짐', '투자', '지다', '아파트', '전', '목적', '아빠', '노력', '의견', '빠르다', '며칠', '기억', '완전히', '예술', '사라지다', '의사', '재산', '고치다', '조건', '요', '가리키다', '골', '팔', '올해', '달러', '싸우다', '초', '남', '옳다', '공장', '지원', '질문', '보다', '교회', '층', '강조하다', '기준', '다양하다', '일곱', '경험', '언론', '봄', '나타내다', '낮다', '원하다', '참다', '주제', '강하다', '요구하다', '대답', '아기', '빠지다', '오십', '이곳', '프로그램', '주', '열심히', '섬', '여름', '생산', '구', '공부하다', '받아들이다', '사고', '부자', '아이', '자동차', '키우다', '자주', '현재', '벽', '밝다', '장', '틀리다', '넓다', '계속하다', '겨울', '여섯', '언제', '영국', '독일', '달리다', '양', '수업', '흔들다', '대답하다', '원인', '어깨', '프랑스', '여전히', '법', '별', '수사', '실제로', '위', '가격', '결정', '부산', '백만', '유럽', '선수', '건물', '짧다', '살', '전통', '화', '그룹', '알아보다', '지식', '혹시', '재미있다', '앞서다', '미치다', '언제나', '누르다', '목표', '종이', '멈추다', '버스', '나머지', '도로', '일어서다', '해', '말', '북', '분석', '쏘다', '바위', '가져오다', '미치다', '작년', '치료', '취하다', '준비하다', '제품', '아홉', '행정', '경영', '셋', '오', '지구', '저것', '맞다', '인정하다', '발견하다', '약속', '인터넷', '직원', '선배', '고통', '즐기다', '군대', '밀다', '존재하다', '일반적', '결혼하다', '고등학교', '똥', '사십', '숨다', '발생하다', '뉴스', '모', '평화', '종교', '마르다', '결정하다', '거리', '가끔', '천만', '이쪽', '복', '여행', '견디다', '해결하다', '가을', '유명하다', '총리', '켜다', '별', '여덟', '전', '막히다', '예쁘다' ...
#
# -------------
# JAPANESE
# Found 3978 unmatched words in Japanese from the list of 5000 words
#
# Removed 1022 words from the word list
# >> 0 were stopwords:
#     []
#
# >> 1022 already exist in CAS:
#     ['の', 'に', 'は', 'た', 'を', 'が', 'て', 'と', 'も', '言う', 'あの', 'する', 'の', 'ある', 'ね', 'なる', 'か', 'その', '思う', 'か', 'が', '物', 'そう', '何', 'と', '私', 'それ', 'この', '行く', 'これ', 'もう', '時', 'な', '人', 'よ', 'ば', 'や', '来る', 'その', '見る', '今', '所', '自分', 'ん', 'やる', '中', 'いる', 'できる', 'また', 'ちょっと', 'だけ', '方', 'へ', 'どう', 'し', '本当', '持つ', 'そこ', 'う', '入る', '作る', '聞く', '話', 'そんな', '使う', '風', '前', '多い', 'よく', '一つ', '子供', '気', '取る', '知る', 'ここ', 'とても', 'いろいろ', '一', 'そう', '一番', '二', '必要', '仕事', '彼', '方', '食べる', '入れる', '次', '問題', '例えば', '目', '上', '他', 'いつ', '家', '日', '一人', 'どこ', '時間', 'だから', '違う', '受ける', '言葉', '買う', 'まだ', '手', '意味', '三', '間', '最近', '特に', '誰', '友達', '大きい', 'すぐ', '一緒', '生活', '国', 'あなた', '現在', '高い', '悪い', '気持ち', '乗る', '見える', '会社', '実際', '先生', '彼女', '二人', '心', 'あの', 'ある', '金', '顔', 'ずっと', 'たくさん', 'もちろん', '読む', '今日', '昔', 'うん', '教える', '子', '水', '場所', '楽しい', '声', '最後', '車', '初めて', '体', '歩く', '女性', '学校', '生きる', 'もっと', 'テーマ', '世界', 'と', 'もし', '飲む', '新しい', 'の', '会う', 'アメリカ', 'あれ', '小さい', '母', '関係', '四', 'たぶん', '店', '頭', '本', 'こちら', 'わ', '夜', '者', '全部', '皆さん', '毎日', 'おいしい', '家族', '部分', '結果', '少ない', '他', '父', '方法', '部屋', 'ちょうど', '大学', '朝', '選ぶ', '面白い', 'やめる', '下', '始める', '犬', '嬉しい', '遊ぶ', '理由', '女', '今回', '人生', '通り', 'テレビ', '木', '点', '自然', '音', '海', '働く', '近く', '足', '切る', '待つ', '写真', '二つ', '五', '忘れる', '口', '送る', '道', 'しかも', '難しい', '彼ら', '山', 'すでに', '年', '花', '情報', '開く', '当たる', '近い', '結婚', '歴史', '音楽', '外', '駅', 'はい', '映画', '客', '質問', '地域', 'どうしても', '見せる', '一日', '今年', '安い', '夢', 'どちら', '色', '探す', 'ちゃんと', '興味', '三つ', '売る', '変化', '夏', 'よる', '事件', '中国', '目的', '病気', '午後', '困る', '環境', '高校', '火', '社会', '練習', '怖い', '広い', '猫', '向こう', '六', '場', 'ホテル', '夫', '数', '意見', '大丈夫', '通う', '可能性', '三人', '料理', 'きっと', 'どうして', '歌う', 'ぞ', '新聞', '歌', '開ける', '着る', '違い', '記憶', '思い出', '四月', 'いくら', '魚', '旅行', '健康', '味', '戦争', '男性', '電車', '着く', '厳しい', '活動', '研究', '大人', '島', '機会', 'さ', '三月', 'ニュース', '聞こえる', '過去', 'やっと', '悲しい', '雨', 'ひどい', '昨日', 'メール', '耳', '表現', '注意', '間', '将来', '自転車', '川', '法律', '妻', '冬', '七', '手紙', '出かける', '努力', 'おそらく', '船', '九月', 'きっかけ', '授業', '茶', '直接', 'バス', '効果', '現実', '飼う', '国民', '十月', '特徴', '雑誌', '建物', '止まる', '十二月', '突然', '首', '目指す', '一月', '八月', '七月', '五月', '優しい', '後ろ', '六月', '十一月', '飛行機', '種類', '胸', '運動', '捨てる', '横', '命', '予定', '馬', '学生', '風', '近所', '海外', '教育', '実は', '文化', '八', '食べ物', '借りる', '二月', 'や', '月', 'インターネット', '春', '旅', '寒い', '年', '責任', '技術', '記事', 'たまに', '慣れる', '出会う', 'たび', '付き合う', '条件', '医者', '秋', '明るい', '選手', '調査', '空', '明日', '役割', '地球', '公園', '激しい', '短い', '薬', '試合', 'おなか', 'ボール', '方向', 'タイプ', 'ヨーロッパ', '一週間', '何回', '政府', '量', '田舎', '地元', '寂しい', '希望', 'フランス', '疲れる', '落とす', '患者', '壁', '道路', '去年', '肩', '匂い', 'ありがとう', '右', '安心', '雪', '十', '知識', '緑', '時々', '野菜', '自分自身', '血', '涙', '次第', '警察', '兄', '腰', '開催', '窓', 'ドア', '森', '腕', '手術', '一日', '愛する', '施設', 'データ', 'ピアノ', '議論', '出来事', '安全', '事故', '要る', '鳥', '市', '眠る', '固い', '値段', 'トイレ', '野球', '洗う', '左', '制度', 'チーム', '九', '番組', '傾向', 'レベル', 'ドイツ', '主に', 'パン', '肉', '指', '態度', '地', '助ける', '権利', '痛み', '返す', '庭', '組織', '人口', '治療', 'サービス', '荷物', '村', 'あそこ', '韓国', '字', '経営', '南', '成立', '季節', 'い', '先輩', 'コミュニケーション', '散歩', 'エネルギー', '携帯', '休む', '甘い', '弟', '服', '赤ちゃん', '妹', '小説', '汗', '咲く', '暑い', '利益', '姉', '黒', 'プロ', '舞台', '弾く', '喜び', 'スキー', '椅子', '桜', 'ゲーム', '試験', '恥ずかしい', '金', '皮', '白', '抜く', '敵', '側', '祭り', '幼稚園', '分野', '間違う', '土', 'それとも', '三日', '席', '歯', 'ベッド', '星', '太陽', 'ワイン', '高校生', '二日', 'たまる', '冷たい', '宗教', '範囲', '政治', 'パリ', '奥さん', '遅れる', '機械', '費用', '誘う', '土', 'アルバイト', '北', '一生', '植物', '契約', 'マンガ', 'ドラマ', '髪', 'サッカー', '工場', '監督', '階段', 'オーストラリア', '鼻', 'すみません', 'コーヒー', '商店街', '笑顔', '真ん中', 'ビール', 'ラジオ', '入る', '床', '社長', '経済', '温泉', '肌', '職場', '平和', '間違い', 'けんか', '熱い', '出会い', '上司', 'け', '急ぐ', '犯人', '熱', '犯罪', '出発', '教師', '日曜日', '楽器', 'カメラ', 'ビデオ', '今日', '生', '応援', 'どうぞ', '四つ', '未来', 'なくす', 'が', 'イタリア', '汚い', '履く', '業務', '幸い', '夜中', '結婚式', '到着', 'かく', '医師', '国家', '十一', '別れる', '掃除', '保険', 'もの', '景色', 'アジア', '電気', '市民', '分かりやすい', '製品', '構造', '対策', '図書館', '街', '世代', 'ごめんなさい', '画面', '物語', '来年', 'テニス', 'アパート', 'ギター' ...
